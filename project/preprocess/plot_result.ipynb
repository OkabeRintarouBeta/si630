# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_loss=[1.386563254847671,1.3768653676551077,1.3526572785927262,1.3323512861558644,1.3103547592938427,1.162025826808178,1.1396116617107739,1.1170266065393362,1.0999311189698227,1.0855186369272813,0.8813294225870961,0.8905937378817629,0.8907843008651627,0.8902392050878257,0.8905604302928589,0.6592722936523984,0.6397222966050646,0.6464520212449429,0.6510367859840585,0.3975631569711085,0.40038018025643585,0.40539235018686903,0.4109100283790165]

# %%
eval_loss=[1.0964473637863785,0.9197493560383911,0.8819074710016463,0.9181000406731926]
eval_acc=[0.5452646239554317,0.6399721448467967,0.6483286908077994,0.6601671309192201]

# %%
len_x=len(train_loss)
steps=[i for i in range(1,len_x+1)]

# %%
sns.lineplot(x=steps,y=train_loss)
plt.xlabel('steps(1000)')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
epoch=[i for i in range(1,5)]
# df=pd.DataFrame({'epoch':step_eval,'loss':eval_loss,'accuracy':eval_acc})
# sns.lineplot(x='epoch',y='value',hue='variable',data=pd.melt(df,['epoch']))
plt.figure(figsize = (12,6))

plt.subplot(1, 2, 1)
plt.plot(epoch,eval_loss)
plt.title("Eval Set Loss")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.subplot(1, 2, 2)
plt.plot(epoch,eval_acc)
plt.title("Eval Set Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')


plt.tight_layout(4)
plt.show()
# Out:
# /Users/liuzihui/miniconda3/envs/python37/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Passing the pad parameter of tight_layout() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.

# %%
sns.lineplot(x=step_eval,y=eval_acc)
# Out:
# <AxesSubplot:>
